# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# df = pd.read_csv("diabetes.csv")
# df = pd.read_csv("diabetes_prediction_dataset.csv")
df = pd.read_csv("user_data.csv")
df.head()
# Out:
#    gender  age  hypertension  heart_disease  smoking_history    bmi  \
# 0       1   30             1              1                0  25.00
# 1       1   30             1              1                0  48.48
# 2       1   30             1              1                0  48.48
# 3       1   30             1              1                0  48.48
# 4       0   15             1              1                0  22.06
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0         5.00               100.00         0
# 1         5.00               100.00         0
# 2        15.00               100.00         1
# 3         4.02               100.00         0
# 4        10.92                 9.62         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               7 non-null      int64
#  1   age                  7 non-null      int64
#  2   hypertension         7 non-null      int64
#  3   heart_disease        7 non-null      int64
#  4   smoking_history      7 non-null      int64
#  5   bmi                  7 non-null      float64
#  6   HbA1c_level          7 non-null      float64
#  7   blood_glucose_level  7 non-null      float64
#  8   diabetes             7 non-null      int64
# dtypes: float64(3), int64(6)
# memory usage: 632.0 bytes
